# %% [markdown]
# Por Gabriel Garcia Caysahuana \
# Con datos de https://finance.yahoo.com/
#
# Acciones de empresas en análisis: \
# MSFT: Microsoft Corporation\
# TSLA: Tesla, Inc.\
# NVDA: NVIDIA Corporation\
# AAPL: Apple Inc.\
# GOOG: Alphabet Inc. (compañía matriz de Google)\
# AMZN: Amazon.com, Inc.\
# AMD: Advanced Micro Devices, Inc.\
# SBUX: Starbucks Corporation

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.36-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.26.3)
# Requirement already satisfied: requests>=2.31 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.1.0-cp312-cp312-win_amd64.whl.metadata (3.6 kB)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pytz>=2022.5 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.0.tar.gz (314 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.17.0.tar.gz (2.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.12.3)
# Collecting html5lib>=1.1 (from yfinance)
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2023.11.17)
# Downloading yfinance-0.2.36-py2.py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/72.4 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/72.4 kB ? eta -:--:--
#    ---------------------------------------- 72.4/72.4 kB 1.3 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp312-cp312-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.9 MB 4.1 MB/s eta 0:00:01
#    - -------------------------------------- 0.2/3.9 MB 2.4 MB/s eta 0:00:02
#    --- ------------------------------------ 0.3/3.9 MB 2.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.4/3.9 MB 2.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.6/3.9 MB 2.4 MB/s eta 0:00:02
#    ------ --------------------------------- 0.7/3.9 MB 2.3 MB/s eta 0:00:02
#    ------- -------------------------------- 0.8/3.9 MB 2.5 MB/s eta 0:00:02
#    --------- ------------------------------ 0.9/3.9 MB 2.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.1/3.9 MB 2.7 MB/s eta 0:00:02
#    ------------ --------------------------- 1.3/3.9 MB 2.7 MB/s eta 0:00:01
#    -------------- ------------------------- 1.4/3.9 MB 2.7 MB/s eta 0:00:01
#    --------------- ------------------------ 1.5/3.9 MB 2.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.7/3.9 MB 2.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.9/3.9 MB 2.9 MB/s eta 0:00:01
#    -------------------- ------------------- 2.0/3.9 MB 2.9 MB/s eta 0:00:01
#    --------------------- ------------------ 2.2/3.9 MB 2.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.3/3.9 MB 2.9 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------- -------------- 2.5/3.9 MB 2.9 MB/s eta 0:00:01
#    --------------------------- ------------ 2.7/3.9 MB 2.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.8/3.9 MB 2.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.9/3.9 MB 2.9 MB/s eta 0:00:01
#    ------------------------------ --------- 3.0/3.9 MB 2.9 MB/s eta 0:00:01
#    -------------------------------- ------- 3.2/3.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.3/3.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/3.9 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.5/3.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 3.6/3.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 3.6/3.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 3.6/3.9 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 2.7 MB/s eta 0:00:00
# Building wheels for collected packages: frozendict, peewee
#   Building wheel for frozendict (pyproject.toml): started
#   Building wheel for frozendict (pyproject.toml): finished with status 'done'
#   Created wheel for frozendict: filename=frozendict-2.4.0-py3-none-any.whl size=15471 sha256=e752f38f2ae3a5abcaf88192b6a6c64048b74f1662e598a7470dd0af6df5fd62
#   Stored in directory: c:\users\pc sitos\appdata\local\pip\cache\wheels\f8\24\61\a7327cee6da6ddddd619cddf13acfb4ec63606c69bbfe31486
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.0-py3-none-any.whl size=135766 sha256=facb59048485a4700c7a98f976b61456f87933bf3e001cbad0b5902daf4478bb
#   Stored in directory: c:\users\pc sitos\appdata\local\pip\cache\wheels\35\c2\ce\d5490cdd71c6d4a993c87a5e172ec23c5d9cd287b59b7f8098
# Successfully built frozendict peewee
# Installing collected packages: peewee, multitasking, appdirs, lxml, html5lib, frozendict, yfinance
# Successfully installed appdirs-1.4.4 frozendict-2.4.0 html5lib-1.1 lxml-5.1.0 multitasking-0.0.11 peewee-3.17.0 yfinance-0.2.36
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyPortfolioOpt
# Out:
# Collecting PyPortfolioOpt
#   Using cached pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
# Collecting cvxpy<2.0.0,>=1.1.19 (from PyPortfolioOpt)
#   Downloading cvxpy-1.4.2.tar.gz (1.6 MB)
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.6 MB 393.8 kB/s eta 0:00:04
#      -- ------------------------------------- 0.1/1.6 MB 819.2 kB/s eta 0:00:02
#      ----- ---------------------------------- 0.2/1.6 MB 1.1 MB/s eta 0:00:02
#      ------ --------------------------------- 0.3/1.6 MB 1.1 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.4/1.6 MB 1.5 MB/s eta 0:00:01
#      ------------- -------------------------- 0.5/1.6 MB 1.6 MB/s eta 0:00:01
#      --------------- ------------------------ 0.6/1.6 MB 1.7 MB/s eta 0:00:01
#      ------------------- -------------------- 0.8/1.6 MB 1.8 MB/s eta 0:00:01
#      ---------------------- ----------------- 0.9/1.6 MB 2.0 MB/s eta 0:00:01
#      -------------------------- ------------- 1.0/1.6 MB 2.0 MB/s eta 0:00:01
#      ------------------------------ --------- 1.2/1.6 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 1.4/1.6 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 1.5/1.6 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 2.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from PyPortfolioOpt) (1.26.3)
# Requirement already satisfied: pandas>=0.19 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from PyPortfolioOpt) (2.1.4)
# Requirement already satisfied: scipy<2.0,>=1.3 in c:\users\pc sitos\appdata\local\programs\python\python312\lib\site-packages (from PyPortfolioOpt) (1.12.0)
# Collecting osqp>=0.6.2 (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt)
#   Downloading osqp-0.6.3.tar.gz (228 kB)
#      ---------------------------------------- 0.0/228.4 kB ? eta -:--:--
#      ------ -------------------------------- 41.0/228.4 kB 2.0 MB/s eta 0:00:01
#      ----------------------- -------------- 143.4/228.4 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 228.4/228.4 kB 2.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [299 lines of output]
#   Collecting oldest-supported-numpy
#     Downloading oldest_supported_numpy-2023.12.21-py3-none-any.whl.metadata (9.8 kB)
#   Collecting setuptools>=40.8.0
#     Using cached setuptools-69.0.3-py3-none-any.whl.metadata (6.3 kB)
#   Collecting wheel
#     Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
#   Collecting setuptools_scm>=6.2
#     Downloading setuptools_scm-8.0.4-py3-none-any.whl.metadata (6.4 kB)
#   Collecting qdldl
#     Downloading qdldl-0.1.7.post0.tar.gz (70 kB)
#        ---------------------------------------- 0.0/71.0 kB ? eta -:--:--
#        ----- ---------------------------------- 10.2/71.0 kB ? eta -:--:--
#        --------------------- ---------------- 41.0/71.0 kB 487.6 kB/s eta 0:00:01
#        -------------------------------------- 71.0/71.0 kB 646.3 kB/s eta 0:00:00
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Installing backend dependencies: started
#     Installing backend dependencies: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
#     Preparing metadata (pyproject.toml): finished with status 'done'
#   Collecting numpy==1.26.2 (from oldest-supported-numpy)
#     Downloading numpy-1.26.2-cp312-cp312-win_amd64.whl.metadata (61 kB)
#        ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#        ------------------------- ------------ 41.0/61.2 kB 653.6 kB/s eta 0:00:01
#        -------------------------------------- 61.2/61.2 kB 822.1 kB/s eta 0:00:00
#   Collecting packaging>=20 (from setuptools_scm>=6.2)
#     Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
#   Collecting typing-extensions (from setuptools_scm>=6.2)
#     Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
#   Collecting scipy>=0.13.2 (from qdldl)
#     Using cached scipy-1.12.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#   Downloading oldest_supported_numpy-2023.12.21-py3-none-any.whl (4.9 kB)
#   Downloading numpy-1.26.2-cp312-cp312-win_amd64.whl (15.5 MB)
#      ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.5 MB 991.0 kB/s eta 0:00:16
#      ---------------------------------------- 0.1/15.5 MB 1.7 MB/s eta 0:00:10
#       --------------------------------------- 0.2/15.5 MB 1.8 MB/s eta 0:00:09
#       --------------------------------------- 0.3/15.5 MB 1.7 MB/s eta 0:00:09
#       --------------------------------------- 0.3/15.5 MB 1.6 MB/s eta 0:00:10
#      - -------------------------------------- 0.4/15.5 MB 1.7 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/15.5 MB 1.8 MB/s eta 0:00:09
#      - -------------------------------------- 0.7/15.5 MB 1.9 MB/s eta 0:00:08
#      - -------------------------------------- 0.7/15.5 MB 1.8 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/15.5 MB 1.9 MB/s eta 0:00:08
#      -- ------------------------------------- 0.9/15.5 MB 1.9 MB/s eta 0:00:08
#      -- ------------------------------------- 1.0/15.5 MB 1.8 MB/s eta 0:00:09
#      -- ------------------------------------- 1.0/15.5 MB 1.8 MB/s eta 0:00:09
#      -- ------------------------------------- 1.1/15.5 MB 1.8 MB/s eta 0:00:09
#      --- ------------------------------------ 1.2/15.5 MB 1.8 MB/s eta 0:00:09
#      --- ------------------------------------ 1.3/15.5 MB 1.8 MB/s eta 0:00:08
#      --- ------------------------------------ 1.4/15.5 MB 1.8 MB/s eta 0:00:09
#      --- ------------------------------------ 1.4/15.5 MB 1.8 MB/s eta 0:00:08
#      --- ------------------------------------ 1.5/15.5 MB 1.8 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.6/15.5 MB 1.8 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.7/15.5 MB 1.8 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.8/15.5 MB 1.8 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.9/15.5 MB 1.8 MB/s eta 0:00:08
#      ----- ---------------------------------- 2.0/15.5 MB 1.8 MB/s eta 0:00:08
#      ----- ---------------------------------- 2.1/15.5 MB 1.8 MB/s eta 0:00:08
#      ----- ---------------------------------- 2.2/15.5 MB 1.8 MB/s eta 0:00:08
#      ----- ---------------------------------- 2.3/15.5 MB 1.8 MB/s eta 0:00:08
#      ------ --------------------------------- 2.3/15.5 MB 1.8 MB/s eta 0:00:08
#      ------ --------------------------------- 2.4/15.5 MB 1.8 MB/s eta 0:00:08
#      ------ --------------------------------- 2.6/15.5 MB 1.8 MB/s eta 0:00:08
#      ------ --------------------------------- 2.7/15.5 MB 1.9 MB/s eta 0:00:07
#      ------- -------------------------------- 2.8/15.5 MB 1.9 MB/s eta 0:00:07
#      ------- -------------------------------- 2.9/15.5 MB 1.9 MB/s eta 0:00:07
#      ------- -------------------------------- 2.9/15.5 MB 1.9 MB/s eta 0:00:07
#      ------- -------------------------------- 3.0/15.5 MB 1.9 MB/s eta 0:00:07
#      -------- ------------------------------- 3.1/15.5 MB 1.9 MB/s eta 0:00:07
#      -------- ------------------------------- 3.3/15.5 MB 1.9 MB/s eta 0:00:07
#      -------- ------------------------------- 3.4/15.5 MB 1.9 MB/s eta 0:00:07
#      --------- ------------------------------ 3.5/15.5 MB 1.9 MB/s eta 0:00:07
#      --------- ------------------------------ 3.6/15.5 MB 2.0 MB/s eta 0:00:07
#      --------- ------------------------------ 3.7/15.5 MB 1.9 MB/s eta 0:00:07
#      --------- ------------------------------ 3.8/15.5 MB 1.9 MB/s eta 0:00:07
#      --------- ------------------------------ 3.9/15.5 MB 1.9 MB/s eta 0:00:07
#      ---------- ----------------------------- 4.0/15.5 MB 1.9 MB/s eta 0:00:06
#      ---------- ----------------------------- 4.1/15.5 MB 2.0 MB/s eta 0:00:06
#      ---------- ----------------------------- 4.2/15.5 MB 2.0 MB/s eta 0:00:06
#      ----------- ---------------------------- 4.3/15.5 MB 2.0 MB/s eta 0:00:06
#      ----------- ---------------------------- 4.4/15.5 MB 2.0 MB/s eta 0:00:06
#      ----------- ---------------------------- 4.5/15.5 MB 2.0 MB/s eta 0:00:06
#      ----------- ---------------------------- 4.5/15.5 MB 2.0 MB/s eta 0:00:06
#      ----------- ---------------------------- 4.6/15.5 MB 2.0 MB/s eta 0:00:06
#      ------------ --------------------------- 4.7/15.5 MB 1.9 MB/s eta 0:00:06
#      ------------ --------------------------- 4.9/15.5 MB 2.0 MB/s eta 0:00:06
#      ------------ --------------------------- 5.0/15.5 MB 2.0 MB/s eta 0:00:06
#      ------------- -------------------------- 5.1/15.5 MB 2.0 MB/s eta 0:00:06
#      ------------- -------------------------- 5.1/15.5 MB 2.0 MB/s eta 0:00:06
#      ------------- -------------------------- 5.3/15.5 MB 2.0 MB/s eta 0:00:06
#      -------------- ------------------------- 5.4/15.5 MB 2.0 MB/s eta 0:00:06
#      -------------- ------------------------- 5.6/15.5 MB 2.0 MB/s eta 0:00:05
#      -------------- ------------------------- 5.7/15.5 MB 2.0 MB/s eta 0:00:05
#      -------------- ------------------------- 5.8/15.5 MB 2.0 MB/s eta 0:00:05
#      --------------- ------------------------ 5.9/15.5 MB 2.0 MB/s eta 0:00:05
#      --------------- ------------------------ 6.0/15.5 MB 2.1 MB/s eta 0:00:05
#      --------------- ------------------------ 6.2/15.5 MB 2.1 MB/s eta 0:00:05
#      ---------------- ----------------------- 6.3/15.5 MB 2.1 MB/s eta 0:00:05
#      ---------------- ----------------------- 6.4/15.5 MB 2.1 MB/s eta 0:00:05
#      ---------------- ----------------------- 6.6/15.5 MB 2.1 MB/s eta 0:00:05
#      ----------------- ---------------------- 6.6/15.5 MB 2.1 MB/s eta 0:00:05
#      ----------------- ---------------------- 6.7/15.5 MB 2.1 MB/s eta 0:00:05
#      ----------------- ---------------------- 6.8/15.5 MB 2.1 MB/s eta 0:00:05
#      ----------------- ---------------------- 7.0/15.5 MB 2.1 MB/s eta 0:00:05
#      ------------------ --------------------- 7.1/15.5 MB 2.1 MB/s eta 0:00:05
#      ------------------ --------------------- 7.2/15.5 MB 2.1 MB/s eta 0:00:04
#      ------------------ --------------------- 7.3/15.5 MB 2.1 MB/s eta 0:00:04
#      ------------------ --------------------- 7.4/15.5 MB 2.1 MB/s eta 0:00:04
#      ------------------- -------------------- 7.5/15.5 MB 2.1 MB/s eta 0:00:04
#      ------------------- -------------------- 7.7/15.5 MB 2.1 MB/s eta 0:00:04
#      -------------------- ------------------- 7.8/15.5 MB 2.1 MB/s eta 0:00:04
#      -------------------- ------------------- 7.9/15.5 MB 2.2 MB/s eta 0:00:04
#      -------------------- ------------------- 8.0/15.5 MB 2.2 MB/s eta 0:00:04
#      -------------------- ------------------- 8.1/15.5 MB 2.1 MB/s eta 0:00:04
#      -------------------- ------------------- 8.1/15.5 MB 2.1 MB/s eta 0:00:04
#      -------------------- ------------------- 8.1/15.5 MB 2.1 MB/s eta 0:00:04
#      --------------------- ------------------ 8.2/15.5 MB 2.1 MB/s eta 0:00:04
#      --------------------- ------------------ 8.3/15.5 MB 2.1 MB/s eta 0:00:04
#      --------------------- ------------------ 8.4/15.5 MB 2.1 MB/s eta 0:00:04
#      --------------------- ------------------ 8.4/15.5 MB 2.1 MB/s eta 0:00:04
#      --------------------- ------------------ 8.5/15.5 MB 2.1 MB/s eta 0:00:04
#      ---------------------- ----------------- 8.6/15.5 MB 2.1 MB/s eta 0:00:04
#      ---------------------- ----------------- 8.6/15.5 MB 2.1 MB/s eta 0:00:04
#      ---------------------- ----------------- 8.7/15.5 MB 2.1 MB/s eta 0:00:04
#      ---------------------- ----------------- 8.8/15.5 MB 2.1 MB/s eta 0:00:04
#      ---------------------- ----------------- 8.9/15.5 MB 2.0 MB/s eta 0:00:04
#      ----------------------- ---------------- 8.9/15.5 MB 2.0 MB/s eta 0:00:04
#      ----------------------- ---------------- 9.0/15.5 MB 2.0 MB/s eta 0:00:04
#      ----------------------- ---------------- 9.1/15.5 MB 2.0 MB/s eta 0:00:04
#      ----------------------- ---------------- 9.1/15.5 MB 2.0 MB/s eta 0:00:04
#      ----------------------- ---------------- 9.2/15.5 MB 2.0 MB/s eta 0:00:04
#      ----------------------- ---------------- 9.3/15.5 MB 2.0 MB/s eta 0:00:04
#      ------------------------ --------------- 9.3/15.5 MB 2.0 MB/s eta 0:00:04
#      ------------------------ --------------- 9.4/15.5 MB 2.0 MB/s eta 0:00:04
#      ------------------------ --------------- 9.5/15.5 MB 2.0 MB/s eta 0:00:04
#      ------------------------ --------------- 9.5/15.5 MB 2.0 MB/s eta 0:00:04
#      ------------------------ --------------- 9.6/15.5 MB 2.0 MB/s eta 0:00:03
#      ------------------------- -------------- 9.7/15.5 MB 2.0 MB/s eta 0:00:03
#      ------------------------- -------------- 9.8/15.5 MB 2.0 MB/s eta 0:00:03
#      ------------------------- -------------- 9.9/15.5 MB 2.0 MB/s eta 0:00:03
#      -------------------------- ------------- 10.1/15.5 MB 2.0 MB/s eta 0:00:03
#      -------------------------- ------------- 10.3/15.5 MB 2.0 MB/s eta 0:00:03
#      -------------------------- ------------- 10.4/15.5 MB 2.0 MB/s eta 0:00:03
#      --------------------------- ------------ 10.5/15.5 MB 2.0 MB/s eta 0:00:03
#      --------------------------- ------------ 10.6/15.5 MB 2.1 MB/s eta 0:00:03
#      --------------------------- ------------ 10.8/15.5 MB 2.1 MB/s eta 0:00:03
#      ---------------------------- ----------- 10.9/15.5 MB 2.1 MB/s eta 0:00:03
#      ---------------------------- ----------- 11.0/15.5 MB 2.1 MB/s eta 0:00:03
#      ---------------------------- ----------- 11.2/15.5 MB 2.1 MB/s eta 0:00:03
#      ----------------------------- ---------- 11.3/15.5 MB 2.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 11.4/15.5 MB 2.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 11.6/15.5 MB 2.1 MB/s eta 0:00:02
#      ------------------------------ --------- 11.7/15.5 MB 2.2 MB/s eta 0:00:02
#      ------------------------------ --------- 11.9/15.5 MB 2.2 MB/s eta 0:00:02
#      ------------------------------ --------- 12.0/15.5 MB 2.2 MB/s eta 0:00:02
#      ------------------------------- -------- 12.1/15.5 MB 2.2 MB/s eta 0:00:02
#      ------------------------------- -------- 12.3/15.5 MB 2.2 MB/s eta 0:00:02
#      ------------------------------- -------- 12.4/15.5 MB 2.2 MB/s eta 0:00:02
#      -------------------------------- ------- 12.5/15.5 MB 2.2 MB/s eta 0:00:02
#      -------------------------------- ------- 12.7/15.5 MB 2.2 MB/s eta 0:00:02
#      -------------------------------- ------- 12.8/15.5 MB 2.2 MB/s eta 0:00:02
#      --------------------------------- ------ 12.9/15.5 MB 2.2 MB/s eta 0:00:02
#      --------------------------------- ------ 13.0/15.5 MB 2.2 MB/s eta 0:00:02
#      --------------------------------- ------ 13.1/15.5 MB 2.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 13.2/15.5 MB 2.2 MB/s eta 0:00:02
#      ---------------------------------- ----- 13.3/15.5 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 13.4/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 13.6/15.5 MB 2.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 13.7/15.5 MB 2.3 MB/s eta 0:00:01
#      ----------------------------------- ---- 13.8/15.5 MB 2.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 13.9/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------ --- 14.0/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------ --- 14.1/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------ --- 14.2/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------ --- 14.3/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------- -- 14.4/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------- -- 14.6/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------- -- 14.6/15.5 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------- -- 14.7/15.5 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 14.8/15.5 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 14.8/15.5 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 14.9/15.5 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 15.0/15.5 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 15.1/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.2/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.3/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.3/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.4/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 15.5/15.5 MB 2.0 MB/s eta 0:00:00
#   Using cached setuptools-69.0.3-py3-none-any.whl (819 kB)
#   Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
#   Downloading setuptools_scm-8.0.4-py3-none-any.whl (42 kB)
#      ---------------------------------------- 0.0/42.1 kB ? eta -:--:--
#      ---------------------------------------- 42.1/42.1 kB 1.0 MB/s eta 0:00:00
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ---------------------------------------- 0.0/53.0 kB ? eta -:--:--
#      ---------------------------------------- 53.0/53.0 kB 1.4 MB/s eta 0:00:00
#   Using cached scipy-1.12.0-cp312-cp312-win_amd64.whl (45.8 MB)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
#   Building wheels for collected packages: qdldl
#     Building wheel for qdldl (pyproject.toml): started
#     Building wheel for qdldl (pyproject.toml): finished with status 'error'
#     error: subprocess-exited-with-error
#
#     Building wheel for qdldl (pyproject.toml) did not run successfully.
#     exit code: 1
#
#     [73 lines of output]
#     running bdist_wheel
#     running build
#     running build_ext
#     Traceback (most recent call last):
#       File "<string>", line 81, in build_extensions
#       File "C:\Users\PC SITOS\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 466, in check_output
#         return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\PC SITOS\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#         with Popen(*popenargs, **kwargs) as process:
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\PC SITOS\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
#         self._execute_child(args, executable, preexec_fn, close_fds,
#       File "C:\Users\PC SITOS\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1538, in _execute_child
#         hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     FileNotFoundError: [WinError 2] El sistema no puede encontrar el archivo especificado
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\PC SITOS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#         main()
#       File "C:\Users\PC SITOS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\PC SITOS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 251, in build_wheel
#         return _build_backend().build_wheel(wheel_directory, config_settings,
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\build_meta.py", line 404, in build_wheel
#         return self._build_with_temp_dir(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\build_meta.py", line 389, in _build_with_temp_dir
#         self.run_setup()
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\build_meta.py", line 311, in run_setup
#         exec(code, locals())
#       File "<string>", line 113, in <module>
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\__init__.py", line 103, in setup
#         return distutils.core.setup(**attrs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#         return run_commands(dist)
#                ^^^^^^^^^^^^^^^^^^
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#         dist.run_commands()
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\dist.py", line 963, in run_command
#         super().run_command(command)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#         cmd_obj.run()
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\normal\Lib\site-packages\wheel\bdist_wheel.py", line 368, in run
#         self.run_command("build")
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\dist.py", line 963, in run_command
#         super().run_command(command)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#         cmd_obj.run()
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#         self.run_command(cmd_name)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\dist.py", line 963, in run_command
#         super().run_command(command)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#         cmd_obj.run()
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\command\build_ext.py", line 88, in run
#         _build_ext.run(self)
#       File "C:\Users\PC SITOS\AppData\Local\Temp\pip-build-env-npma15n3\overlay\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 345, in run
#         self.build_extensions()
#       File "<string>", line 83, in build_extensions
#     RuntimeError: CMake must be installed to build qdldl
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#     ERROR: Failed building wheel for qdldl
#   Failed to build qdldl
#   ERROR: Could not build wheels for qdldl, which is required to install pyproject.toml-based projects
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import seaborn as sns
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# Símbolos de los activos del portafolio
tickers = ["MSFT", "TSLA",'NVDA', 'AAPL','GOOG','AMZN', 'AMD','SBUX']

# %%
# Obtener datos históricos de los activos de Yahoo Finance
data = yf.download(tickers, start="2023-01-16", end="2024-01-16")["Adj Close"].dropna()

# Calcular rendimientos diarios
for ticker in tickers:
    data[f'R{ticker}'] = np.log(data[ticker] / data[ticker].shift(1))
data=data.dropna()
# Out:
# [*********************100%%**********************]  8 of 8 completed

# %%
data.describe().T
# Out:
#        count        mean         std         min         25%         50%  \
# AAPL   249.0  174.274534   15.352550  134.458450  164.662048  176.778076
# AMD    249.0  105.910361   17.768642   67.709999   94.559998  106.589996
# AMZN   249.0  123.668635   18.543122   90.730003  103.629997  128.149994
# GOOG   249.0  121.576727   15.713280   89.349998  106.120003  125.059998
# MSFT   249.0  318.319403   39.652007  229.891571  286.551453  326.597137
# NVDA   249.0  379.359598  102.426005  167.575623  272.185486  423.097961
# SBUX   249.0   99.400290    4.781819   88.990990   96.042244   99.046143
# TSLA   249.0  222.096907   36.866241  127.169998  191.149994  233.190002
# RMSFT  249.0    0.001964    0.015327   -0.038364   -0.007516    0.001609
# RTSLA  249.0    0.002047    0.032539   -0.102540   -0.016550    0.002672
# RNVDA  249.0    0.004533    0.029278   -0.060889   -0.013155    0.003744
# RAAPL  249.0    0.001280    0.012609   -0.049211   -0.006211    0.001266
# RGOOG  249.0    0.001799    0.019219   -0.100914   -0.009208    0.001475
# RAMZN  249.0    0.001912    0.020272   -0.088083   -0.009786    0.001074
# RAMD   249.0    0.002877    0.029496   -0.096735   -0.014689    0.000824
# RSBUX  249.0   -0.000515    0.014090   -0.096219   -0.007891   -0.000389
#
#               75%         max
# AAPL   187.403107  198.110001
# AMD    116.809998  149.259995
# AMZN   138.070007  155.179993
# GOOG   134.699997  144.240005
# MSFT   339.859192  388.470001
# NVDA   460.909485  548.219971
# SBUX   103.101685  112.768089
# TSLA   253.179993  293.339996
# RMSFT    0.010919    0.069931
# RTSLA    0.019654    0.104362
# RNVDA    0.019341    0.218088
# RAAPL    0.008416    0.045859
# RGOOG    0.011973    0.070142
# RAMZN    0.015364    0.079452
# RAMD     0.020409    0.118921
# RSBUX    0.006831    0.090572

# %%
print(type(data[ticker]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Crear una figura con dos subgráficos
fig, ax = plt.subplots(figsize=(12, 7))
# Graficar los precios históricos de JNJ, MSFT, NVDA y TSLA en un solo gráfico
for ticker in tickers:
    sns.lineplot(data=data, x='Date', y=ticker, label=f'adj close {ticker}')
    
# Configurar las etiquetas del eje x y el título del gráfico
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Historical Stock Prices')

# Rotar las etiquetas del eje x para mayor legibilidad
plt.xticks(rotation=45)

# Agregar líneas verticales para cada año
years = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
for year in years:
    # Filtrar los datos por el año actual
    year_data = data[data.index.year == year]
    if len(year_data) > 0:
        # Dibujar una línea vertical en el primer día del año
        plt.axvline(year_data.index[0], linestyle='--', color='gray', linewidth=0.2)
        
# Agregar líneas horizontales en incrementos de 50 para los precios
price_levels = range(0, int(data[ticker].max()), 50)

for level in price_levels:
    plt.axhline(level, linestyle='--', color='gray', linewidth=0.2)
    
# Mostrar la leyenda
plt.legend(loc='upper left')

# Guardar el gráfico
# plt.savefig('Historical Stock Prices.png')

# Mostrar el gráfico
plt.show()

# %%
# Box plot
retornos = {}
for ticker in tickers:
    retornos[f'R{ticker}'] = data[f'R{ticker}'].values

#Creamos una figura con tamaño específico
plt.figure(figsize=(15, 5))

sns.boxplot(data=pd.DataFrame(retornos))
plt.title('Boxplot Analysis of Assets Returns')

# Mostramos el gráfico
plt.show()

# %%
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pypfopt import EfficientFrontier
#       2 from pypfopt import risk_models
#       3 from pypfopt import expected_returns
#
# ModuleNotFoundError: No module named 'pypfopt'

# %%
precios={}
for ticker in tickers:
    precios[ticker] = data[f'{ticker}'].values
mu = expected_returns.mean_historical_return(precios, frequency=252, log_returns=True) #rentabilidades esperadas
Sigma = risk_models.sample_cov(precios) #matriz de covarianza y covarianzas

ef = EfficientFrontier(mu, Sigma) #Frontera de eficiencia
# precios.head()
# Out:
# C:\Anaconda3\Lib\site-packages\pypfopt\expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# C:\Anaconda3\Lib\site-packages\pypfopt\risk_models.py:167: RuntimeWarning: data is not in a dataframe
#   warnings.warn("data is not in a dataframe", RuntimeWarning)

# %%
mu
# Out:
# MSFT    0.626683
# TSLA    0.500413
# NVDA    1.885835
# AAPL    0.362179
# GOOG    0.510231
# AMZN    0.549530
# AMD     0.884886
# SBUX   -0.129308
# dtype: float64

# %%
Sigma
# Out:
#           MSFT      TSLA      NVDA      AAPL      GOOG      AMZN       AMD  \
# MSFT  0.059641  0.041017  0.065679  0.027710  0.038326  0.045504  0.061895
# TSLA  0.041017  0.269579  0.096461  0.044994  0.053657  0.064085  0.082243
# NVDA  0.065679  0.096461  0.232270  0.043067  0.062428  0.061065  0.152723
# AAPL  0.027710  0.044994  0.043067  0.040231  0.032680  0.028086  0.039652
# GOOG  0.038326  0.053657  0.062428  0.032680  0.093055  0.059848  0.067827
# AMZN  0.045504  0.064085  0.061065  0.028086  0.059848  0.104407  0.075639
# AMD   0.061895  0.082243  0.152723  0.039652  0.067827  0.075639  0.224098
# SBUX  0.015654  0.028177  0.022167  0.014696  0.012937  0.017714  0.026997
#
#           SBUX
# MSFT  0.015654
# TSLA  0.028177
# NVDA  0.022167
# AAPL  0.014696
# GOOG  0.012937
# AMZN  0.017714
# AMD   0.026997
# SBUX  0.049816

# %%
# Maximizando el ratio de Sharpe
ef = EfficientFrontier(mu, Sigma)
weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()
ef.portfolio_performance(verbose=True)

# Imprimiendo los pesos de cada activo
cleaned_weights
# Out:
# Expected annual return: 162.8%
# Annual volatility: 41.3%
# Sharpe Ratio: 3.89
# OrderedDict([('MSFT', 0.20453),
#              ('TSLA', 0.0),
#              ('NVDA', 0.79547),
#              ('AAPL', 0.0),
#              ('GOOG', 0.0),
#              ('AMZN', 0.0),
#              ('AMD', 0.0),
#              ('SBUX', 0.0)])

# %% [markdown]
# Un ratio de Sharpe mayor que uno es una señal positiva y sugiere que la cartera o activo en cuestión está superando la tasa libre de riesgo de una manera que podría contribuir a la construcción de una cartera eficiente en términos de rendimiento ajustado al riesgo.
